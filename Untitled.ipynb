# %%
from pandas_datareader import data as web
import pandas as pd
import matplotlib.pyplot as plt

cotacao_bovespa = web.DataReader('^BVSP', data_source='yahoo', start="12/01/2020", end="12/01/2021")
display(cotacao_bovespa)
cotacao_bovespa["Adj Close"].plot()
plt.show()

from pandas_datareader import data as web
import pandas as pd
import matplotlib.pyplot as plt

cotacao_PETRA = web.DataReader('PETR4.SA', data_source='yahoo', start="12/01/2020", end="12/01/2021")
display(cotacao_bovespa)
cotacao_PETRA["Adj Close"].plot(figsize=(15,10))
plt.show()
# Out:
#               High     Low    Open   Close    Volume  Adj Close
# Date
# 2020-12-01  111840  108897  108897  111335  11324800     111335
# 2020-12-02  112315  110579  111402  111814   9814300     111814
# 2020-12-03  113377  111874  111874  112919  11474200     112919
# 2020-12-04  113864  112294  112294  113682   8892900     113682
# 2020-12-07  114531  112629  113751  113625   9633900     113625
# ...            ...     ...     ...     ...       ...        ...
# 2021-11-25  106400  104514  104514  105811   7890400     105811
# 2021-11-26  105810  101495  105810  102224  10969100     102224
# 2021-11-29  104149  102226  102227  102814  10283300     102814
# 2021-11-30  103066  100075  102814  101915  18195100     101915
# 2021-12-01  104087  100727  101916  100775  13762900     100775
#
# [247 rows x 6 columns]
#               High     Low    Open   Close    Volume  Adj Close
# Date
# 2020-12-01  111840  108897  108897  111335  11324800     111335
# ...

# %%
tabela_empresas = pd.read_excel("Empresas.xlsx")
display(tabela_empresas)


for empresa in tabela_empresas['Empresas']:
    print(empresa)
    cotacao = web.DataReader(f'{empresa}.SA', data_source='yahoo', start="12/01/2020", end="12/01/2021")
    display(cotacao)
    cotacao["Adj Close"].plot(figsize=(15,10))
    plt.show()
# Out:
#   Empresas
# 0    ITUB4
# 1    PETR4
# 2    BBDC4
# 3    VALE3
# ITUB4
#                  High        Low       Open      Close      Volume  Adj Close
# Date
# 2020-12-01  30.469999  28.940001  29.049999  29.750000  51364700.0  28.568945
# 2020-12-02  30.240000  29.440001  29.920000  29.980000  32159500.0  28.789816
# 2020-12-03  30.879999  29.900000  30.139999  29.959999  39887800.0  28.770611
# 2020-12-04  30.410000  29.650000  30.219999  30.260000  35096600.0  29.058699
# 2020-12-07  31.059999  30.030001  30.250000  30.440001  30663100.0  29.231558
# ...               ...        ...        ...        ...         ...        ...
# 2021-11-25  23.490000  23.049999  23.100000  23.250000  17767700.0  23.151386
# 2021-11-26  22.959999  22.480000  22.760000  22.809999  32284000.0  22.713251
# 2021-11-29  23.190001  22.600000  23.070000  22.660000  33714000.0  22.563889
# 2021-11-30  22.750000  22.049999  22.680000  22.379999  61042700.0  22.285078
# ...
